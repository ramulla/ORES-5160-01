# %% [markdown]
# <a href="https://colab.research.google.com/github/ramulla/ORES-5160-01/blob/main/week13/week13_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mobility_df = pd.read_csv('/content/2022_US_Region_Mobility_Report.csv')

# %%
mobility_df.shape
# Out:
# (747969, 15)

# %% [markdown]
# The COVID-19 mobility Dataset has 747969 rows and 15 columns.
#
# Let's also take a look at the data in the cell below

# %%
mobility_df.tail()
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 747964                  US  United States      Wyoming  Weston County
# 747965                  US  United States      Wyoming  Weston County
# 747966                  US  United States      Wyoming  Weston County
# 747967                  US  United States      Wyoming  Weston County
# 747968                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 747964         NaN             NaN           56045.0
# 747965         NaN             NaN           56045.0
# 747966         NaN             NaN           56045.0
# 747967         NaN             NaN           56045.0
# 747968         NaN             NaN           56045.0
#
#                            place_id        date  \
# 747964  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-10-10
# 747965  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-10-11
# 747966  ChIJd4Rqhed3YocR7ubT5-HgoJg  2022-10-12
# ...

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
unique_val_col = mobility_df.nunique()
print(unique_val_col)
# Out:
# country_region_code                                      1
# country_region                                           1
# sub_region_1                                            51
# sub_region_2                                          1697
# metro_area                                               0
# iso_3166_2_code                                         51
# census_fips_code                                      2810
# place_id                                              2863
# date                                                   288
# retail_and_recreation_percent_change_from_baseline     369
# grocery_and_pharmacy_percent_change_from_baseline      288
# parks_percent_change_from_baseline                     603
# transit_stations_percent_change_from_baseline          399
# workplaces_percent_change_from_baseline                186
# residential_percent_change_from_baseline                58
# dtype: int64

# %% [markdown]
# We can see the the number of unique values each column has through the cell above.
# The column with most unique values is 'census_fips_code'. But we won't be using that column for our project. So amongst the columns we do use, the highest unique values belong to 'parks_percent_change_from_baseline', with 603 unique values.

# %%
value_counts = mobility_df['sub_region_1'].value_counts()
value_counts
# Out:
# Texas                   55177
# Georgia                 39114
# Virginia                34967
# North Carolina          27564
# Missouri                27158
# Kentucky                26826
# Indiana                 25779
# Illinois                25749
# Ohio                    25265
# Tennessee               25188
# Iowa                    24293
# Michigan                22142
# Minnesota               21535
# Mississippi             19647
# Wisconsin               19439
# Florida                 18979
# Pennsylvania            18805
# Alabama                 18550
# Arkansas                18186
# New York                17856
# Oklahoma                17793
# Louisiana               16546
# California              16218
# Kansas                  15620
# South Carolina          13291
# Nebraska                12851
# Colorado                12847
# West Virginia           12255
# Washington              10208
# Oregon                   9638
# Idaho                    9393
# ...

# %% [markdown]
# We counted the number of unique entries each state has. And as we can see texas has the highest number of data points.

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
unique_val_col
# Out:
# country_region_code                                      1
# country_region                                           1
# sub_region_1                                            51
# sub_region_2                                          1697
# metro_area                                               0
# iso_3166_2_code                                         51
# census_fips_code                                      2810
# place_id                                              2863
# date                                                   288
# retail_and_recreation_percent_change_from_baseline     369
# grocery_and_pharmacy_percent_change_from_baseline      288
# parks_percent_change_from_baseline                     603
# transit_stations_percent_change_from_baseline          399
# workplaces_percent_change_from_baseline                186
# residential_percent_change_from_baseline                58
# dtype: int64

# %% [markdown]
# As we can see, the 'country_region_code' and 'country_region' have only one unique value. That is because all this data belongs to USA. So those two columns are redundant. And also, 'metro_area' is full of null values. So that column is not needed at all.

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
st_louis_df = mobility_df[mobility_df['sub_region_2'] == 'St. Louis']

# %% [markdown]
# Let's narrow down the data to St. Louis so we can plot meaningful plots

# %%
st_louis_df
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 384108                  US  United States     Missouri    St. Louis
# 384109                  US  United States     Missouri    St. Louis
# 384110                  US  United States     Missouri    St. Louis
# 384111                  US  United States     Missouri    St. Louis
# 384112                  US  United States     Missouri    St. Louis
# ...                    ...            ...          ...          ...
# 384391                  US  United States     Missouri    St. Louis
# 384392                  US  United States     Missouri    St. Louis
# 384393                  US  United States     Missouri    St. Louis
# 384394                  US  United States     Missouri    St. Louis
# 384395                  US  United States     Missouri    St. Louis
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 384108         NaN             NaN           29510.0
# ...

# %%
plt.hist(st_louis_df['parks_percent_change_from_baseline'], bins=20, color='blue', edgecolor='black')
# Out:
# (array([ 5.,  7., 18., 19., 22., 19., 26., 40., 48., 37., 29., 10.,  3.,
#          2.,  2.,  0.,  0.,  0.,  0.,  1.]),
#  array([-70.  , -61.25, -52.5 , -43.75, -35.  , -26.25, -17.5 ,  -8.75,
#           0.  ,   8.75,  17.5 ,  26.25,  35.  ,  43.75,  52.5 ,  61.25,
#          70.  ,  78.75,  87.5 ,  96.25, 105.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# This plot shows the histogram of the 'parks_percent_change_from_baseline' column. As we can see, the number of negative values is high. As the situation from covid was only just improving at this time (through the year 2022) the data is to the left of the baseline

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
dates = pd.to_datetime(st_louis_df['date'])

# %% [markdown]
# let's plot a few time series plots to see how the mobility has chnaged through the year 2022.

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates, st_louis_df['parks_percent_change_from_baseline'], marker='o', linestyle='-', color='b')

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates, st_louis_df['transit_stations_percent_change_from_baseline'], marker='o', linestyle='-', color='b')

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates, st_louis_df['retail_and_recreation_percent_change_from_baseline'], marker='o', linestyle='-', color='b')

# %% [markdown]
# As we can see in all 3 graphs, the mobility has had an upward trend throughout the year. As the situation was improving and people were getting vaccinated, they were more comfortable going outside.

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
